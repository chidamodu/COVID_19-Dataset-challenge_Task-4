# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("/Users/chidam/Desktop/chronic_disease_2011 to 2018.csv")

# %%
df.head()
# Out:
#      Location     2011     2012     2013     2014     2015     2016     2017  \
# 0     Alabama  0.24841  0.26601  0.27281  0.28045  0.27488  0.29151  0.28953
# 1      Alaska  0.19036  0.18906  0.18938  0.17985  0.19457  0.18716  0.19019
# 2     Arizona  0.23042  0.23287  0.23884  0.22779  0.22870  0.24212  0.23646
# 3    Arkansas  0.25388  0.24573  0.24969  0.26373  0.27232  0.27473  0.27199
# 4  California  0.19680  0.21473  0.21414  0.20913  0.20482  0.20747  0.21194
#
#       2018
# 0  0.29298
# 1  0.20854
# 2  0.24829
# 3  0.29448
# 4  0.21328

# %%
df.isnull().sum() * 100 / len(df)

#there are no missing values in the dataset
# Out:
# Location    0.0
# 2011        0.0
# 2012        0.0
# 2013        0.0
# 2014        0.0
# 2015        0.0
# 2016        0.0
# 2017        0.0
# 2018        0.0
# dtype: float64

# %%
df_transpose=df.T

# %%
df_transpose
# Out:
#                0        1        2         3           4         5   \
# Location  Alabama   Alaska  Arizona  Arkansas  California  Colorado
# 2011      0.24841  0.19036  0.23042   0.25388      0.1968   0.17655
# 2012      0.26601  0.18906  0.23287   0.24573     0.21473   0.19225
# 2013      0.27281  0.18938  0.23884   0.24969     0.21414   0.18198
# 2014      0.28045  0.17985  0.22779   0.26373     0.20913   0.18272
# 2015      0.27488  0.19457   0.2287   0.27232     0.20482    0.1872
# 2016      0.29151  0.18716  0.24212   0.27473     0.20747   0.18901
# 2017      0.28953  0.19019  0.23646   0.27199     0.21194   0.19828
# 2018      0.29298  0.20854  0.24829   0.29448     0.21328   0.19177
#
#                    6         7                  8        9   ...         42  \
# Location  Connecticut  Delaware  Dist. of Columbia  Florida  ...  Tennessee
# 2011          0.22433   0.23356             0.2091  0.23472  ...    0.22716
# ...

# %%
df_transpose.to_csv("/Users/chidam/Desktop/chronic_disease_2011 to 2018_transpose.csv")

# %%
df2=pd.read_csv("/Users/chidam/Desktop/chronic_disease_2011 to 2018_transpose.csv")

# %%
df2.head()
# Out:
#    Year  Alabama   Alaska  Arizona  Arkansas  California  Colorado  \
# 0  2011  0.24841  0.19036  0.23042   0.25388     0.19680   0.17655
# 1  2012  0.26601  0.18906  0.23287   0.24573     0.21473   0.19225
# 2  2013  0.27281  0.18938  0.23884   0.24969     0.21414   0.18198
# 3  2014  0.28045  0.17985  0.22779   0.26373     0.20913   0.18272
# 4  2015  0.27488  0.19457  0.22870   0.27232     0.20482   0.18720
#
#    Connecticut  Delaware  Dist. of Columbia  ...  Tennessee    Texas     Utah  \
# 0      0.22433   0.23356            0.20910  ...    0.22716  0.20608  0.18503
# 1      0.22419   0.24404            0.21743  ...    0.25572  0.20981  0.18255
# 2      0.21518   0.25563            0.21974  ...    0.25802  0.20999  0.18691
# 3      0.21716   0.23745            0.22064  ...    0.26549  0.21032  0.18417
# 4      0.22478   0.24502            0.21343  ...    0.26215  0.22454  0.18654
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming  \
# ...

# %%
df2 = df2.set_index('Year')

# %%
df2.plot()

# %%
fig, axes = plt.subplots()
df2['California'].plot(ax=axes, label='California', legend=True)
df2['New York'].plot(ax=axes, label='New York',legend=True)
df2['Alabama'].plot(ax=axes, label='Alabama',legend=True)
df2['Minnesota'].plot(ax=axes, label='Minnesota',legend=True)

# %%
from matplotlib import pyplot
series=df2[['Alabama', 'Iowa', 'Washington', 'New York']]

series.plot()
pyplot.show()

# %%
df2['Alabama'].plot()

# %%
From the above plots it is safe to assume that the data does not exhibit any trend or seasonality. Let us make sure 
of that part by actually plotting trend and seasonality.

# %%
#have tried a ton but decomposition is not working

import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose

# res = sm.tsa.seasonal_decompose(df2.interpolate())
# res.plot()

# %%
# series.index = series.date

# %%
# Multiplicative Decomposition 
result_mul = seasonal_decompose(df2['Alabama'].values, model='multiplicative', freq=1)
result_mul.plot()

# %%
# Additive Decomposition
result_add = seasonal_decompose(df2['Alabama'].values, model='additive', freq=1)
result_add.plot()

# %%
result_add = seasonal_decompose(df2['California'].values, model='additive', freq=1)
result_add.plot()

# %%
Observation re which time series method/model could be fit on the data?

1. Only a simple exponential smoothing is relevant in the context as there is no trend or seasonality in the data.
2. The timing of these cycles is not predictable. Hence the series is stationary - additionally we can check whether the 
series is stationary or not by performing the Dicky Fuller Test.

# %%
df2['Alabama'].values
# Out:
# array([0.24841, 0.26601, 0.27281, 0.28045, 0.27488, 0.29151, 0.28953,
#        0.29298])

# %%
(0.24841+0.26601)/2
# Out:
# 0.25721

# %%
The first step in time series analysis is to try appropriate simple methods to fit the data and forecast future values.
Then move on to advanced ones to get a better model fitted to the data. 
Compare the results of steps: 1 and 2. If the better model does not perform better then there is no reason to choose it.
