# %%
#importing necessary packages

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#importing necessary packages
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# %matplotlib inline
import matplotlib.pyplot as plt  # Matlab-style plotting
import seaborn as sns
color = sns.color_palette()
sns.set_style('darkgrid')
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn #ignore annoying warning (from sklearn and seaborn)


from scipy import stats
from scipy.stats import norm, skew #for some statistics

# %%
#reading from the file
df=pd.read_csv("/Users/chidam/Desktop/chronic_disease_2011 to 2018_transpose.csv")

# %%
df.head()
# Out:
#    Year  Alabama   Alaska  Arizona  Arkansas  California  Colorado  \
# 0  2011  0.24841  0.19036  0.23042   0.25388     0.19680   0.17655
# 1  2012  0.26601  0.18906  0.23287   0.24573     0.21473   0.19225
# 2  2013  0.27281  0.18938  0.23884   0.24969     0.21414   0.18198
# 3  2014  0.28045  0.17985  0.22779   0.26373     0.20913   0.18272
# 4  2015  0.27488  0.19457  0.22870   0.27232     0.20482   0.18720
#
#    Connecticut  Delaware  Dist. of Columbia  ...  Tennessee    Texas     Utah  \
# 0      0.22433   0.23356            0.20910  ...    0.22716  0.20608  0.18503
# 1      0.22419   0.24404            0.21743  ...    0.25572  0.20981  0.18255
# 2      0.21518   0.25563            0.21974  ...    0.25802  0.20999  0.18691
# 3      0.21716   0.23745            0.22064  ...    0.26549  0.21032  0.18417
# 4      0.22478   0.24502            0.21343  ...    0.26215  0.22454  0.18654
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming  \
# ...

# %%
#Let's check the normality plot of the data


sns.distplot(df['Alabama'] , fit=norm);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(df['Alabama'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('Chronic disease in Alabama')

#Get also the QQ-plot
fig = plt.figure()
res = stats.probplot(df['Alabama'], plot=plt)
plt.show()
# Out:
#  mu = 0.28 and sigma = 0.01

# %%
#Let's do box cox transformation and check

#We use the numpy fuction log1p which  applies log(1+x) to all elements of the column
df['Alabama'] = np.log1p(df['Alabama'])

#Check the new distribution 
sns.distplot(df['Alabama'] , fit=norm);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(df['Alabama'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('Chronic disease in Alabama')

#Get also the QQ-plot
fig = plt.figure()
res = stats.probplot(df['Alabama'], plot=plt)
plt.show()
# Out:
#  mu = 0.24 and sigma = 0.01

# %%
Actually the box cox transformation seemed to have only a very little effect so will pass it for now.

# %%
Normality plot of California

sns.distplot(df['California'] , fit=norm);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(df['California'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('Chronic disease in California')

#Get also the QQ-plot
fig = plt.figure()
res = stats.probplot(df['California'], plot=plt)
plt.show()
# Out:
#  mu = 0.21 and sigma = 0.01

# %%
#Let's check the data from 2005 to 2018

dfmerged=pd.read_csv("/Users/chidam/Desktop/chronic_disease_2010 to 2018_transpose.csv")

# %%
dfmerged.head()
# Out:
#    Year  Alabama   Alaska  Arizona  Arkansas  California  Colorado  \
# 0  2005  0.22416  0.15512  0.19757   0.20922     0.18591   0.16351
# 1  2006  0.24919  0.19279  0.22007   0.21224     0.19515   0.16418
# 2  2007  0.24161  0.16294  0.22223   0.21341     0.18317   0.16309
# 3  2008  0.24555  0.18678  0.22114   0.23079     0.19596   0.16963
# 4  2009  0.24750  0.17815  0.23314   0.22782     0.19936   0.17185
#
#    Connecticut  Delaware  Dist. of Columbia  ...  Tennessee    Texas     Utah  \
# 0      0.18675   0.22008            0.19076  ...    0.21610  0.19258  0.16918
# 1      0.19337   0.22571            0.20990  ...    0.23007  0.20222  0.17550
# 2      0.19792   0.21443            0.20054  ...    0.24385  0.21960  0.16393
# 3      0.19063   0.22781            0.19828  ...    0.24107  0.20714  0.17675
# 4      0.18962   0.21349            0.19224  ...    0.21710  0.18996  0.17236
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming  \
# ...

# %%
# Normality plot of Alabama

sns.distplot(dfmerged['Alabama'] , fit=norm);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(dfmerged['Alabama'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('Chronic disease in Alabama')

#Get also the QQ-plot
fig = plt.figure()
res = stats.probplot(dfmerged['Alabama'], plot=plt)
plt.show()
# Out:
#  mu = 0.26 and sigma = 0.02

# %%
#Let's do box cox transformation of Alabama

#We use the numpy fuction log1p which  applies log(1+x) to all elements of the column
dfmerged['Alabama'] = np.log1p(dfmerged['Alabama'])

#Check the new distribution 
sns.distplot(dfmerged['Alabama'] , fit=norm);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(dfmerged['Alabama'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('Chronic disease in Alabama')

#Get also the QQ-plot
fig = plt.figure()
res = stats.probplot(dfmerged['Alabama'], plot=plt)
plt.show()
# Out:
#  mu = 0.23 and sigma = 0.02

# %%
# Normality plot of California
sns.distplot(dfmerged['California'] , fit=norm);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(dfmerged['California'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('Chronic disease in California')

#Get also the QQ-plot
fig = plt.figure()
res = stats.probplot(dfmerged['California'], plot=plt)
plt.show()
# Out:
#  mu = 0.20 and sigma = 0.01
