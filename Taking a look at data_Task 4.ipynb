# %%
#import the necessary packages

import pandas as pd

# %%
Maybe can use this when I needed to do a 1000 foot view with a few popular cities!

Goal: in this notebook I am planning to create the initial time series visualizations involving 4 datasets:

df_2016_with_necessary.csv (actually transformed from:500_Cities__City-level_Data__GIS_Friendly_Format___2016_release.csv)


have to transform the following to fit the style of df_2016_with_necessary.csv:

500_Cities__City-level_Data__GIS_Friendly_Format___2017_release.csv 

500_Cities__City-level_Data__GIS_Friendly_Format___2018_release.csv

500_Cities__City-level_Data__GIS_Friendly_Format___2019_release.csv

# %%
#read from the csv file
df_2016=pd.read_csv("/Users/chidam/Desktop/df_2016_with_necessary.csv")

# %%
#check the top 5 records to get an idea

df_2016.head()
# Out:
#    Unnamed: 0 StateAbbr        PlaceName Population2010  CANCER_AdjPrev  \
# 0           0        FL          Deltona         85,182             6.2
# 1           1        FL  Fort Lauderdale        165,521             6.2
# 2           2        NC     Fayetteville        200,564             5.7
# 3           3        NC         Gastonia         71,741             6.0
# 4           4        CA      Lake Forest         77,264             5.9
#
#    CHD_AdjPrev  KIDNEY_AdjPrev
# 0          6.7             3.1
# 1          6.4             3.2
# 2          6.6             2.7
# 3          7.1             2.7
# 4          4.8             2.2

# %%
#read from the csv file
df_2017=pd.read_csv("/Users/chidam/Desktop/500_Cities__City-level_Data__GIS_Friendly_Format___2017_release.csv")

# %%
df_2017.head()
# Out:
#   StateAbbr   PlaceName PlaceFIPS Population2010  ACCESS2_CrudePrev  \
# 0        AL  Birmingham   107,000        212,237               19.6
# 1        AL      Hoover   135,896         81,619                9.7
# 2        AL  Huntsville   137,000        180,105               15.1
# 3        AL      Mobile   150,000        195,111               16.9
# 4        AL  Montgomery   151,000        205,764               17.4
#
#   ACCESS2_Crude95CI  ACCESS2_AdjPrev ACCESS2_Adj95CI  ARTHRITIS_CrudePrev  \
# 0      (19.2, 20.0)             19.8    (19.5, 20.2)                 30.9
# 1      ( 9.3, 10.1)              9.9    ( 9.5, 10.4)                 25.3
# 2      (14.7, 15.4)             15.1    (14.8, 15.5)                 27.5
# 3      (16.6, 17.2)             17.2    (16.9, 17.5)                 30.5
# 4      (17.0, 17.9)             17.5    (17.1, 17.9)                 29.8
#
#   ARTHRITIS_Crude95CI  ...  SLEEP_Adj95CI STROKE_CrudePrev  STROKE_Crude95CI  \
# ...

# %%
#selecting the necessary columns from the above dataset

df_2017_necessary=df_2017[["StateAbbr","PlaceName","Population2010","CANCER_AdjPrev","CHD_AdjPrev","KIDNEY_AdjPrev"]]

# %%
df_2017_necessary.head()
# Out:
#   StateAbbr   PlaceName Population2010  CANCER_AdjPrev  CHD_AdjPrev  \
# 0        AL  Birmingham        212,237             5.7          7.6
# 1        AL      Hoover         81,619             6.4          4.8
# 2        AL  Huntsville        180,105             6.4          6.2
# 3        AL      Mobile        195,111             6.2          7.2
# 4        AL  Montgomery        205,764             6.2          6.8
#
#    KIDNEY_AdjPrev
# 0             3.5
# 1             2.1
# 2             2.7
# 3             3.1
# 4             3.1

# %%
#The following result demonstrates the significance of grouping by both StateAbbr and PlaceName

df_2017_necessary.loc[df_2017_necessary["PlaceName"]=="Springfield"]
# Out:
#     StateAbbr    PlaceName Population2010  CANCER_AdjPrev  CHD_AdjPrev  \
# 233        IL  Springfield        116,250             6.4          5.8
# 279        MA  Springfield        153,060             5.6          7.5
# 313        MO  Springfield        159,498             6.6          6.6
#
#      KIDNEY_AdjPrev
# 233             2.6
# 279             3.4
# 313             2.8

# %%
#check the length of df_2017_necessary

len(df_2017_necessary)
# Out:
# 500

# %%
#read from the 2018 dataset
df_2018=pd.read_csv("/Users/chidam/Desktop/500_Cities__City-level_Data__GIS_Friendly_Format___2018_release.csv")

# %%
#selecting the necessary columns from the above dataset

df_2018_necessary=df_2018[["StateAbbr","PlaceName","Population2010","CANCER_AdjPrev","CHD_AdjPrev","KIDNEY_AdjPrev"]]

# %%
len(df_2018_necessary)
# Out:
# 500

# %%
#Just to make sure that we are not getting any weird values 

df_2018_necessary.loc[df_2018_necessary["PlaceName"]=="Springfield"]
# Out:
#     StateAbbr    PlaceName Population2010  CANCER_AdjPrev  CHD_AdjPrev  \
# 16         MA  Springfield        153,060             5.8          7.7
# 78         IL  Springfield        116,250             6.4          6.0
# 131        MO  Springfield        159,498             6.5          6.9
#
#      KIDNEY_AdjPrev
# 16              3.6
# 78              2.9
# 131             3.1

# %%
#Let's now read from the 2019 dataset


df_2019=pd.read_csv("/Users/chidam/Desktop/500_Cities__City-level_Data__GIS_Friendly_Format___2019_release.csv")

# %%
#selecting the necessary columns from 2019 dataset

df_2019_necessary=df_2019[["StateAbbr","PlaceName","Population2010","CANCER_AdjPrev","CHD_AdjPrev","KIDNEY_AdjPrev"]]

# %%
len(df_2019_necessary)
# Out:
# 500

# %%
#Can actually see that the column: Population2010 seem to have the same values for all the years. As it should be.

df_2019_necessary.loc[df_2019_necessary["PlaceName"]=="Springfield"]
# Out:
#     StateAbbr    PlaceName Population2010  CANCER_AdjPrev  CHD_AdjPrev  \
# 233        IL  Springfield        116,250             6.4          5.8
# 279        MA  Springfield        153,060             6.0          6.9
# 313        MO  Springfield        159,498             6.6          7.0
#
#      KIDNEY_AdjPrev
# 233             3.0
# 279             3.8
# 313             3.2

# %%
#Now let's dive deeper into how the data was collected and how we can use them in our analysis


#But I have found another data source for prevalence chronic disease from: SHADAC. It has values for a range of years 
#that I guess will be good to forecast values for 2020. Looks promising.
