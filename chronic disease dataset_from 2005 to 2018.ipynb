# %%
#import the necessary packages

import pandas as pd

# %%
About the data source:

SHADAC analysis of the Behavioral Risk Factor Surveillance System (BRFSS) public use files.


SHADAC analysis of [DATA SOURCE], State Health Compare, SHADAC, University of Minnesota, statehealthcompare.shadac.org, 
Accessed [DATE].

# %%
Margin of Error

National estimates represent the total population rate of people who reported this measure.

The margin of error (MOE) represents the uncertainty of an estimate due to sampling variability; the calculated MOE is 
95%. N/A indicates that data were not available or suppressed because the number of sample cases was too small. 

There is a break in series because BRFSS implemented cell phone sampling and an advanced weighting method in 2011.

Percent of adults who report having one or more of the following chronic conditions: diabetes, cardiovascular disease, 
heart attack, stroke and asthma for the civilian non-institutionalized population 18 years and over.

# %%
import pandas as pd

# %%
#read from the prevalence of chronic disease data file: from 2005 to 2010

df1=pd.read_csv("/Users/chidam/Desktop/Shadac-prevalence of chronic disease/Prevalence of Diabetes, CVD and Asthma in Adults by Total (2005 to 2010).csv")

# %%
df1.head()
# Out:
#   Fips       Location  TimeFrame Data Type     Data       MOE
# 0   US  United States       2005   Percent  0.20013  0.000675
# 1   US  United States       2006   Percent  0.20629  0.000769
# 2   US  United States       2007   Percent  0.20780  0.000647
# 3   US  United States       2008   Percent  0.21237  0.000630
# 4   US  United States       2009   Percent  0.21095  0.000629

# %%
# convert rows to columns after group by and populate zeroes for non matching rows - using pd.pivot_table


df_pivot=pd.pivot_table(df1, index='Location', columns='TimeFrame')

# %%
df_pivot.head()
# Out:
#                Data                                                  MOE  \
# TimeFrame      2005     2006     2007     2008     2009     2010    2005
# Location
# Alabama     0.22416  0.24919  0.24161  0.24555  0.24750  0.26443  0.0171
# Alaska      0.15512  0.19279  0.16294  0.18678  0.17815  0.17671  0.0188
# Arizona     0.19757  0.22007  0.22223  0.22114  0.23314  0.23122  0.0197
# Arkansas    0.20922  0.21224  0.21341  0.23079  0.22782  0.21930  0.0125
# California  0.18591  0.19515  0.18317  0.19596  0.19936  0.19509  0.0127
#
#
# TimeFrame     2006    2007     2008     2009     2010
# Location
# Alabama     0.0184  0.0142  0.01610  0.01490  0.01380
# Alaska      0.0219  0.0209  0.02640  0.02180  0.02610
# Arizona     0.0201  0.0216  0.02270  0.02160  0.01840
# Arkansas    0.0126  0.0126  0.01400  0.01750  0.01760
# California  0.0141  0.0124  0.00928  0.00799  0.00744

# %%
#saving a copy of df_pivot in the form of csv 

df_pivot.to_csv("/Users/chidam/Desktop/df_prevalence_chronic_disease_2010.csv")

# %%
#re_reading the csv file saved above with only the data (i.e., without margin of error values)

df2010=pd.read_csv("/Users/chidam/Desktop/df_chronic_disease_without_moe_2010.csv")

# %%
df2010.head()
# Out:
#      Location     2005     2006     2007     2008     2009     2010
# 0     Alabama  0.22416  0.24919  0.24161  0.24555  0.24750  0.26443
# 1      Alaska  0.15512  0.19279  0.16294  0.18678  0.17815  0.17671
# 2     Arizona  0.19757  0.22007  0.22223  0.22114  0.23314  0.23122
# 3    Arkansas  0.20922  0.21224  0.21341  0.23079  0.22782  0.21930
# 4  California  0.18591  0.19515  0.18317  0.19596  0.19936  0.19509

# %%
len(df2010)
# Out:
# 52

# %%
df2010["Location"].values
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Dist. of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'United States'],
#       dtype=object)

# %%
Note:
    
District of Columbia is a federal district and not a state. So in case if I do not have value for DC in the harvard dataset
then I will drop this data point.

Also the dataset has 'United States' as one of the values (for now going to have this around)

# %%
#now let's get the rest of the years for the data in the prevalent chronic disease category



#read from the prevalence of chronic disease data file: from (2011 to 2018)

df2=pd.read_csv("/Users/chidam/Desktop/Shadac-prevalence of chronic disease/Prevalence of Diabetes, CVD and Asthma in Adults by Total (2011 to 2018).csv")

# %%
df2.head()
# Out:
#   Fips       Location  TimeFrame Data Type     Data       MOE
# 0   US  United States       2011   Percent  0.22152  0.000588
# 1   US  United States       2012   Percent  0.22630  0.000627
# 2   US  United States       2013   Percent  0.22870  0.000618
# 3   US  United States       2014   Percent  0.23055  0.000000
# 4   US  United States       2015   Percent  0.22770  0.000625

# %%
# convert rows to columns after group by and populate zeroes for non matching rows - using pd.pivot_table


df_pivot2=pd.pivot_table(df2, index='Location', columns='TimeFrame')

# %%
df_pivot2.head()
# Out:
#                Data                                                        \
# TimeFrame      2011     2012     2013     2014     2015     2016     2017
# Location
# Alabama     0.24841  0.26601  0.27281  0.28045  0.27488  0.29151  0.28953
# Alaska      0.19036  0.18906  0.18938  0.17985  0.19457  0.18716  0.19019
# Arizona     0.23042  0.23287  0.23884  0.22779  0.22870  0.24212  0.23646
# Arkansas    0.25388  0.24573  0.24969  0.26373  0.27232  0.27473  0.27199
# California  0.19680  0.21473  0.21414  0.20913  0.20482  0.20747  0.21194
#
#                          MOE                                             \
# TimeFrame      2018     2011     2012    2013    2014     2015     2016
# Location
# Alabama     0.29298  0.01290  0.01250  0.0148  0.0128  0.01280  0.01390
# Alaska      0.20854  0.01870  0.01580  0.0165  0.0155  0.02120  0.02220
# Arizona     0.24829  0.01830  0.01530  0.0224  0.0104  0.01260  0.01260
# ...

# %%
#saving a copy of df_pivot in the form of csv 

df_pivot2.to_csv("/Users/chidam/Desktop/df_prevalence_chronic_disease_2018.csv")

# %%
#re_reading the csv file saved above with only the data (i.e., without margin of error values)

df2018=pd.read_csv("/Users/chidam/Desktop/df_chronic_disease_without_moe_2018.csv")

# %%
df2018.head()
# Out:
#      Location     2011     2012     2013     2014     2015     2016     2017  \
# 0     Alabama  0.24841  0.26601  0.27281  0.28045  0.27488  0.29151  0.28953
# 1      Alaska  0.19036  0.18906  0.18938  0.17985  0.19457  0.18716  0.19019
# 2     Arizona  0.23042  0.23287  0.23884  0.22779  0.22870  0.24212  0.23646
# 3    Arkansas  0.25388  0.24573  0.24969  0.26373  0.27232  0.27473  0.27199
# 4  California  0.19680  0.21473  0.21414  0.20913  0.20482  0.20747  0.21194
#
#       2018
# 0  0.29298
# 1  0.20854
# 2  0.24829
# 3  0.29448
# 4  0.21328

# %%
df2018.tail()
# Out:
#          Location     2011     2012     2013     2014     2015     2016  \
# 47     Washington  0.21678  0.21335  0.21599  0.21445  0.21016  0.22178
# 48  West Virginia  0.26665  0.29557  0.28082  0.30994  0.30111  0.31896
# 49      Wisconsin  0.21027  0.20445  0.22211  0.22148  0.22207  0.22514
# 50        Wyoming  0.21213  0.21808  0.21668  0.20522  0.20197  0.22314
# 51  United States  0.22152  0.22630  0.22870  0.23055  0.22770  0.23296
#
#        2017     2018
# 47  0.22527  0.22582
# 48  0.32492  0.32963
# 49  0.21290  0.21095
# 50  0.22378  0.20816
# 51  0.23319  0.24101

# %%
len(df2018)
# Out:
# 52

# %%
#I have merged the above two datasets: df2010 and df2018 and reading from the merged file
#note: leaving the margin of error for now


dfmerged=pd.read_csv("/Users/chidam/Desktop/chronic_disease_2010 to 2018.csv")

# %%
len(dfmerged)
# Out:
# 52

# %%
dfmerged.head()
# Out:
#      Location     2005     2006     2007     2008     2009     2010     2011  \
# 0     Alabama  0.22416  0.24919  0.24161  0.24555  0.24750  0.26443  0.24841
# 1      Alaska  0.15512  0.19279  0.16294  0.18678  0.17815  0.17671  0.19036
# 2     Arizona  0.19757  0.22007  0.22223  0.22114  0.23314  0.23122  0.23042
# 3    Arkansas  0.20922  0.21224  0.21341  0.23079  0.22782  0.21930  0.25388
# 4  California  0.18591  0.19515  0.18317  0.19596  0.19936  0.19509  0.19680
#
#       2012     2013     2014     2015     2016     2017     2018
# 0  0.26601  0.27281  0.28045  0.27488  0.29151  0.28953  0.29298
# 1  0.18906  0.18938  0.17985  0.19457  0.18716  0.19019  0.20854
# 2  0.23287  0.23884  0.22779  0.22870  0.24212  0.23646  0.24829
# 3  0.24573  0.24969  0.26373  0.27232  0.27473  0.27199  0.29448
# 4  0.21473  0.21414  0.20913  0.20482  0.20747  0.21194  0.21328

# %%
dfmerged_transpose=dfmerged.T

# %%
dfmerged_transpose.to_csv("/Users/chidam/Desktop/chronic_disease_2010 to 2018_transpose.csv")

# %%
df_transpose=pd.read_csv("/Users/chidam/Desktop/chronic_disease_2010 to 2018_transpose.csv")

# %%
df_transpose.head()
# Out:
#    Year  Alabama   Alaska  Arizona  Arkansas  California  Colorado  \
# 0  2005  0.22416  0.15512  0.19757   0.20922     0.18591   0.16351
# 1  2006  0.24919  0.19279  0.22007   0.21224     0.19515   0.16418
# 2  2007  0.24161  0.16294  0.22223   0.21341     0.18317   0.16309
# 3  2008  0.24555  0.18678  0.22114   0.23079     0.19596   0.16963
# 4  2009  0.24750  0.17815  0.23314   0.22782     0.19936   0.17185
#
#    Connecticut  Delaware  Dist. of Columbia  ...  Tennessee    Texas     Utah  \
# 0      0.18675   0.22008            0.19076  ...    0.21610  0.19258  0.16918
# 1      0.19337   0.22571            0.20990  ...    0.23007  0.20222  0.17550
# 2      0.19792   0.21443            0.20054  ...    0.24385  0.21960  0.16393
# 3      0.19063   0.22781            0.19828  ...    0.24107  0.20714  0.17675
# 4      0.18962   0.21349            0.19224  ...    0.21710  0.18996  0.17236
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming  \
# ...

# %%
df_transpose = df_transpose.set_index('Year')

# %%
df_transpose.head()
# Out:
#       Alabama   Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# Year
# 2005  0.22416  0.15512  0.19757   0.20922     0.18591   0.16351      0.18675
# 2006  0.24919  0.19279  0.22007   0.21224     0.19515   0.16418      0.19337
# 2007  0.24161  0.16294  0.22223   0.21341     0.18317   0.16309      0.19792
# 2008  0.24555  0.18678  0.22114   0.23079     0.19596   0.16963      0.19063
# 2009  0.24750  0.17815  0.23314   0.22782     0.19936   0.17185      0.18962
#
#       Delaware  Dist. of Columbia  Florida  ...  Tennessee    Texas     Utah  \
# Year                                        ...
# 2005   0.22008            0.19076  0.21337  ...    0.21610  0.19258  0.16918
# 2006   0.22571            0.20990  0.21297  ...    0.23007  0.20222  0.17550
# 2007   0.21443            0.20054  0.20138  ...    0.24385  0.21960  0.16393
# 2008   0.22781            0.19828  0.21661  ...    0.24107  0.20714  0.17675
# ...

# %%
#Let's plot the above data to understand patterns, trend, and seasonality

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_transpose.plot()

Observation:
On a high level it looks like the patterns exhibit trend and seasonality changes.

# %%
#Let dive deeper with a fewer states.


fig, axes = plt.subplots()
df_transpose['California'].plot(ax=axes, label='California', legend=True)
df_transpose['New York'].plot(ax=axes, label='New York',legend=True)
df_transpose['Alabama'].plot(ax=axes, label='Alabama',legend=True)
df_transpose['Minnesota'].plot(ax=axes, label='Minnesota',legend=True)


Observation:
A non-linear trend becomes visible from Alabama, New York, California, and Minnesota. For some states it is midly 
increasing and for others it is vastly increasing.


Trend:
A trend exists when there is a long-term increase or decrease in the data. It does not have to be linear. Sometimes we 
will refer to a trend as “changing direction”, when it might go from an increasing trend to a decreasing trend.

# %%
#Let's try to understand whether seasonality exists
# Seasonality:
# A seasonal pattern occurs when a time series is affected by seasonal factors such as the time of the year or the day 
# of the week. Seasonality is always of a fixed and known frequency. 


# Because the data does not have info on month, day, and week, the plotting based on freq did not work
# df_transpose["California"].asfreq('Y').plot() # asfreq method is used to convert a time series to a specified frequency. 
# # Here it is monthly frequency.
# plt.title('Chronic disease in California over time(Monthly frequency)')
# plt.show()

# %%
Point to note:
There is a break in series because BRFSS implemented cell phone sampling and an advanced weighting method in 2011.

BRFSS surveys a sample of adults in each state to get information on health risks and behaviors, health practices for 
preventing disease, and healthcare access mostly linked to chronic disease and injury. The sample is representative of 
the population of each state.

The second change is to replace the “post-stratification” weighting method with a more advanced method called 
“iterative proportional fitting,” also sometimes called “raking.”


-------------------------------------------------------------------------------------------------------------------------


Can the 2010 BRFSS dataset be compared with 2011 dataset? (from: https://www.cdc.gov/surveillancepractice/reports/brfss/brfss_faqs.html)
It is always difficult to discern long-term trends by comparing one year to the next. Such comparisons will be 
especially difficult to make for 2010 and 2011, given the change in BRFSS methods.

Changes in the 2011 data are likely to show indications of somewhat higher occurrences of risk behaviors common to 
younger adults and to certain racial or ethnic minority groups. Such effects will vary for each state survey.
CDC anticipates small increases for health-risk indicators such as tobacco use, obesity, binge drinking, HIV, asthma, 
and health status.

Shifts in observed prevalence from 2010 to 2011 for BRFSS measures will likely reflect the new methods of measuring 
risk factors, rather than true trends in risk-factor prevalence.


-------------------------------------------------------------------------------------------------------------------------
Because I am using the datasets after the updates I think I should be fine.

-------------------------------------------------------------------------------------------------------------------------
Idea for data sources:

Can also check each county public health department for data?

-------------------------------------------------------------------------------------------------------------------------

# %%
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.api as sm

# %%
df_transpose.reset_index(inplace=True)
df_transpose['Year'] = pd.to_datetime(df_transpose['Year'])
df_transpose = df_transpose.set_index('Year')

# %%
df_transpose.head()
# Out:
#                                index  Alabama   Alaska  Arizona  Arkansas  \
# Year
# 1970-01-01 00:00:00.000002005      0  0.22416  0.15512  0.19757   0.20922
# 1970-01-01 00:00:00.000002006      1  0.24919  0.19279  0.22007   0.21224
# 1970-01-01 00:00:00.000002007      2  0.24161  0.16294  0.22223   0.21341
# 1970-01-01 00:00:00.000002008      3  0.24555  0.18678  0.22114   0.23079
# 1970-01-01 00:00:00.000002009      4  0.24750  0.17815  0.23314   0.22782
#
#                                California  Colorado  Connecticut  Delaware  \
# Year
# 1970-01-01 00:00:00.000002005     0.18591   0.16351      0.18675   0.22008
# 1970-01-01 00:00:00.000002006     0.19515   0.16418      0.19337   0.22571
# 1970-01-01 00:00:00.000002007     0.18317   0.16309      0.19792   0.21443
# 1970-01-01 00:00:00.000002008     0.19596   0.16963      0.19063   0.22781
# 1970-01-01 00:00:00.000002009     0.19936   0.17185      0.18962   0.21349
#
# ...

# %%
#Assuming that there is no clear trend and seasonality, I am going with the simple exponential smoothing

Remember that Simple exponential smoothing has a “flat” forecast function and these forecasts will only be suitable 
if the time series has no trend or seasonal component.

# %%
Because of the following reason: I am planning to include the data from 2011 to 

It is always difficult to discern long-term trends by comparing one year to the next. Such comparisons will be 
especially difficult to make for 2010 and 2011, given the change in BRFSS methods.

# %%
result_add = seasonal_decompose(df_transpose['California'].values, model='additive', freq=1)
result_add.plot()

# %%
df_transpose['Alabama'].values
# Out:
# array([0.22416, 0.24919, 0.24161, 0.24555, 0.2475 , 0.26443, 0.24841,
#        0.26601, 0.27281, 0.28045, 0.27488, 0.29151, 0.28953, 0.29298])

# %%
result_alabama = seasonal_decompose(df_transpose['Alabama'].values, model='additive', freq=1)
result_alabama.plot()
